# %% [markdown]
# <a href="https://colab.research.google.com/github/TraoAnTan/AI/blob/main/AI_W3_17_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LOAD LIBRARY
import pandas as pd
#CREAT dataframe
dataframe = pd.DataFrame()
#ADD colums
dataframe  ['Name'] = ['Lemon', 'aplle', 'banana']
dataframe  ['Price'] =[5,8,7]
dataframe  ['License'] = [False, True, True]
#SHOW DATA
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   aplle      8     True
# 2  banana      7     True

# %% [markdown]
# # New Section

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df = dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
#print colums name

# %%
df.describe()
# Out:
#           Price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
# loc iloc
df.loc[(df.Price==5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Name =='lemon')]
# Out:
# Empty DataFrame
# Columns: [Name, Price, License]
# Index: []

# %%
df.loc[(df.Name =='Lemon')]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price==5) | (df.Name =='banana') ]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  banana      7     True

# %%
df.loc[(df.Price == 5)| (df.Name == 'banana'), ['Name','Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  banana      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
# Out:
#      Name  Price  License
# 2  banana      7     True

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  aplle      8     True

# %%
df.iloc[0:2,0:-1]
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 20

# %%
max = df.Price.max()
print(max)
# Out:
# 8

# %%
#creat row data
new = pd.Series(['Orange',10, True], index= ['Name', 'Price','License'])
dataframe.append(new, ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   aplle      8     True
# 2  banana      7     True
# 3  Orange     10     True

# %%
# append a colums
dataframe ['Location'] = ['VN', 'LAO','CAM']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False       VN
# 1   aplle      8     True      LAO
# 2  banana      7     True      CAM

# %%
#delete a colum
dataframe.drop('Location', axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   aplle      8     True
# 2  banana      7     True

# %%
#replace
dataframe['Price'].replace(5,7).head(3)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
#rename colums
dataframe.rename(columns = {'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False       VN
# 1   aplle     8     True      LAO
# 2  banana     7     True      CAM

# %%
import pandas as pd
dataframe = pd.read_csv('medals.csv')
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
list(dataframe.columns)
# Out:
# ['Year',
#  'City',
#  'Sport',
#  'Discipline',
#  'NOC',
#  'Event',
#  'Event gender',
#  'Medal']

# %%
dataframe.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event', 'Event gender',
#        'Medal'],
#       dtype='object')

# %%
dataframe.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
dataframe.iloc[0:2,0:-1]
# Out:
#    Year      City    Sport      Discipline  NOC       Event Event gender
# 0  1924  Chamonix  Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix  Skating  Figure skating  AUT  individual            W

# %%
dataframe.iloc[0:2,-1]
# Out:
# 0    Silver
# 1      Gold
# Name: Medal, dtype: object

# %%
sum = dataframe.Medal.sum()
print(sum)
# Out:
# ...

# %%
dataframe.set_index(['NOC'])
# Out:
#      Year      City       Sport      Discipline            Event Event gender  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating       individual            M
# AUT  1924  Chamonix     Skating  Figure skating       individual            W
# AUT  1924  Chamonix     Skating  Figure skating            pairs            X
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# ..    ...       ...         ...             ...              ...          ...
# USA  2006     Turin      Skiing       Snowboard        Half-pipe            M
# USA  2006     Turin      Skiing       Snowboard        Half-pipe            W
# USA  2006     Turin      Skiing       Snowboard        Half-pipe            W
# USA  2006     Turin      Skiing       Snowboard  Snowboard Cross            M
# USA  2006     Turin      Skiing       Snowboard  Snowboard Cross            W
#
#       Medal
# NOC
# ...

# %%
dataframe.iloc[0:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
dataframe.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data = dataframe.set_index(dataframe['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...
